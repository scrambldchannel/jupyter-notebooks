# %% [markdown]
# # Cricket Statistics and Python
#
# Inspired by an enthralling Ashes series, I wanted to play around with cricket data available from various free and commercial sources out there.. Despite a bit of trawling, I couldn't really find a single document detailing what was available.
#
# ## So what sources are there?
#
# I did a bit of Googling and also looked at what some of the obvious sites offered. Additionally, I looked for existing python libraries and played around with them. I was more interested in being able to crunch stats as opposed to create widgets showing live scores, for example, but have looked at everything.
#
# ### Cricinfo
#
# Every web literate person with even a passing interest in cricket will know Cricinfo. It's been owned by ESPN for years now and various old questions on Stack Exchange at Quora suggest they used to have an API for developers but that it was discontinued. That said, there are still some options for grabbing their data by leveraging feeds or scraping pages.
#
# #### RSS Feeds
#
# This page lists the available rss feeds. These can be parsed to get information on current matches and recent results.
#
# http://www.espncricinfo.com/ci/content/rss/feeds_rss_cricket.html
#
# #### Python libraries
#
# Searching on Github returns [quite a few results](https://github.com/search?l=Python&q=cricinfo&type=Repositories) but most are old and unloved. A couple stood out though (there are probably more of interest):
#
# ##### Cricpy
#
# Provides a wealth of functions for scraping html pages as seems to be under active development. Has low level functions that pull data and dump to csv for local analysis as well as functions to create charts and perform statistical analysis. Seems geared towards people doing statistical analysis rather than creating apps. I definitely need to explore in more depth.
#
# https://github.com/tvganesh/cricpy
#
# ##### python-espncricinfo
#
# This is a simpler library that uses a combination of scraping as well as leveraging some (as far as I can tell) undocumented json files available on cricinfo. It doesn't seem to be under active development though and some functions have bugs and some don't work at all. That said, it gave me an interesting insight into some data I didn't realise was easily accessible.
#
# https://github.com/dwillis/python-espncricinfo
#
#
# ### Cricbuzz
#
# I'll confess to never really looking at Cricbuzz but it is another popular site dedicated to cricket news. There is a python library for accessing it.
#
# #### pycricbuzz
#
# I haven't really taken a look at this yet but it does seem to have been updated recently and have quite a few stargazers and forks.
#
# https://github.com/codophobia/pycricbuzz
#
#
# ### Cricapi
#
# This is a freemium api offering a free key that grants you 100 calls per day. It gives useful info about current matches and and individual player stats but is probably more geared toward app developers than people just wanting to do analysis.
#
# https://www.cricapi.com/
#
# #### pycricapi
#
# There is a library here that provides a basic wrapper for each endpoint.
#
# https://github.com/KarthikGangadhar/pycricapi
#
# ### Rapid API
#
# A few things turn up when searching Rapid API but I haven't really looked at them so far.
#
# https://rapidapi.com/search/cricket
#
# This seems to offer 2500 hits per day and a relatively cheap pricing model after that. Again it's geared toward app developers rather than statisticians.
#
# https://rapidapi.com/dev132/api/cricket-live-scores/
#
#
# ### Sportradar
#
# Sportradar offer a number of different APIs for different sports. It's a premium service (ie quite expensive) but does provide some pretty useful stuff. I took advantage of their free trial and played around with a bit but I am limited to 1000 calls as part of the trial so haven't explored too much.
#
# #### SportradarAPIs (python wrapper)
#
# A wrapper already existed but didn't include a class to access the cricket endpoints so I added them.
#
# https://github.com/johnwmillr/SportradarAPIs
#
# ### Sportmonks
#
# Sportmonks are another service providing APIs for all sorts of sports. They offer a free trial for 14 days but I haven't taken them up on this yet but might revisit this if I have a bit of time to make the most of it.
#
# https://www.sportmonks.com/cricket-api - 14 day trial available
#
# ### Cricket API
#
# I found this which is another premium service but without any option for a free trial that I could see. I've not looked at it beyond that.
#
# https://www.cricketapi.com/

# %% [markdown]
# *

# %%
# Trying to do something useful with the cricinfo RSS feeds

import requests
import xml.etree.ElementTree as ET

r = requests.get('http://static.cricinfo.com/rss/livescores.xml')
tree = ET.ElementTree(ET.fromstring(r.text))
root = tree.getroot() 
item = root.findall('channel/item')

for entry in item:
    score = format(entry.findtext('title'))
    match_id = entry.findtext('guid').split('.')[2].split('/')[4]
    print("{0} - {1}".format(score, match_id))
# Out:
# These are the ongoing games as of now and their match ids
#
# Balochistan v Central Punjab (Pakistan) - 1199401
# Northern (Pakistan) v Sindh - 1199402
# Khyber Pakhtunkhwa v Southern Punjab (Pakistan) - 1199403
# New Zealand Under-19s v Bangladesh Under-19s - 1202033
# Victoria 168/10 * v Queensland 322/9  - 1196098
# South Australia 228/9  v Tasmania 229/5 * - 1196099
# Malaysia 134/9 * v Vanuatu 151/5  - 1202007
# Andhra 38 * v Chhattisgarh 268/9  - 1200635
# Goa 266/8  v Jharkhand 37/2 * - 1200768
# Hyderabad (India) 11/1 * v Kerala 226/9  - 1200766
# Baroda v Punjab - 1200769
# Haryana v Uttar Pradesh - 1200771
# Himachal Pradesh v Maharashtra - 1200638
# Chandigarh v Manipur - 1200765
# Mizoram v Nagaland - 1200692
# Sri Lanka A v Bangladesh A - 1201025
# Australia Women 217/4  v Sri Lanka Women 176/7 * - 1183510
# United Services Recreation Club 67/10  v Hong Kong Cricket Club 69/4 * - 1197541
# Pakistan Association of Hong Kong 79/4 * v Kowloon Cricket Club 140/10  - 1197542
# Singapore v Zimbabwe - 1201682
# India Women v South Africa Women - 1198480
# Barbados Tridents v St Lucia Zouks - 1185862

# %%
# Let's pick one of these matches and pull the json file for it

#http://www.espncricinfo.com/matches/engine/match/{0}.json
import json

r = requests.get('http://www.espncricinfo.com/matches/engine/match/1196099.json')
r.json()
# Out:
# {'centre': {},
#  'comms': [{'ball': [{'comms_id': '',
#      'dismissal': '',
#      'event': '1 run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '47',
#      'overs_actual': '46.2',
#      'overs_unique': '46.02',
#      'players': 'Valente to Faulkner',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': '',
#      'event': '1 run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '47',
#      'overs_actual': '46.1',
#      'overs_unique': '46.01',
#      'players': 'Valente to McDermott',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''}],
#    'innings_number': '2',
#    'over_number': '47'},
#   {'ball': [{'comms_id': '',
#      'dismissal': '',
#      'event': '1 run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '46',
#      'overs_actual': '45.6',
#      'overs_unique': '45.07',
#      'players': 'Pope to McDermott',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': '',
#      'event': '1 run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '46',
#      'overs_actual': '45.5',
#      'overs_unique': '45.06',
#      'players': 'Pope to Faulkner',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': '',
#      'event': '1 wide',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '46',
#      'overs_actual': '45.5',
#      'overs_unique': '45.05',
#      'players': 'Pope to Faulkner',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': '',
#      'event': 'no run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '46',
#      'overs_actual': '45.4',
#      'overs_unique': '45.04',
#      'players': 'Pope to Faulkner',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': 'BJ Webster c Head b Pope 0 (1b 0x4 0x6) SR: 0.00',
#      'event': 'OUT',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '46',
#      'overs_actual': '45.3',
#      'overs_unique': '45.03',
#      'players': 'Pope to Webster',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': '',
#      'event': '1 run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '46',
#      'overs_actual': '45.2',
#      'overs_unique': '45.02',
#      'players': 'Pope to McDermott',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': '',
#      'event': 'no run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '46',
#      'overs_actual': '45.1',
#      'overs_unique': '45.01',
#      'players': 'Pope to McDermott',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''}],
#    'batsman': [{'balls_faced': '139',
#      'fours': '6',
#      'live_current_name': 'striker',
#      'player_id': '70392',
#      'runs': '102',
#      'sixes': '1'},
#     {'balls_faced': '2',
#      'fours': '0',
#      'live_current_name': 'non-striker',
#      'player_id': '50483',
#      'runs': '1',
#      'sixes': '0'}],
#    'bowler': [{'conceded': '43',
#      'live_current_name': 'current bowler',
#      'maidens': '0',
#      'overs': '7.0',
#      'player_id': '96336',
#      'wickets': '1'},
#     {'conceded': '40',
#      'live_current_name': 'previous bowler',
#      'maidens': '0',
#      'overs': '9.0',
#      'player_id': '70473',
#      'wickets': '1'}],
#    'event_string': '4 runs',
#    'innings_number': '2',
#    'over_complete': '1',
#    'over_number': '46',
#    'required_string': '2 runs required from 24 balls, RR: 4.93, RRR: 0.50',
#    'runs': '227',
#    'team_id': '611',
#    'wickets': '5'},
#   {'ball': [{'comms_id': '',
#      'dismissal': 'GJ Bailey  b Valente 6 (5b 0x4 1x6) SR: 120.00',
#      'event': 'OUT',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '45',
#      'overs_actual': '44.6',
#      'overs_unique': '44.06',
#      'players': 'Valente to Bailey',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': '',
#      'event': 'SIX',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '45',
#      'overs_actual': '44.5',
#      'overs_unique': '44.05',
#      'players': 'Valente to Bailey',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': '',
#      'event': 'no run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '45',
#      'overs_actual': '44.4',
#      'overs_unique': '44.04',
#      'players': 'Valente to Bailey',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': '',
#      'event': 'no run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '45',
#      'overs_actual': '44.3',
#      'overs_unique': '44.03',
#      'players': 'Valente to Bailey',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': '',
#      'event': 'no run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '45',
#      'overs_actual': '44.2',
#      'overs_unique': '44.02',
#      'players': 'Valente to Bailey',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': '',
#      'event': '1 run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '45',
#      'overs_actual': '44.1',
#      'overs_unique': '44.01',
#      'players': 'Valente to McDermott',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''}],
#    'batsman': [{'balls_faced': '136',
#      'fours': '6',
#      'live_current_name': 'non-striker',
#      'player_id': '70392',
#      'runs': '100',
#      'sixes': '1'}],
#    'bowler': [{'conceded': '40',
#      'live_current_name': 'current bowler',
#      'maidens': '0',
#      'overs': '9.0',
#      'player_id': '70473',
#      'wickets': '1'},
#     {'conceded': '39',
#      'live_current_name': 'previous bowler',
#      'maidens': '0',
#      'overs': '6.0',
#      'player_id': '96336',
#      'wickets': '0'}],
#    'event_string': '7 runs',
#    'innings_number': '2',
#    'over_complete': '1',
#    'over_number': '45',
#    'required_string': '6 runs required from 30 balls, RR: 4.95, RRR: 1.20',
#    'runs': '223',
#    'team_id': '611',
#    'wickets': '4'},
#   {'ball': [{'comms_id': '',
#      'dismissal': '',
#      'event': '1 run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '44',
#      'overs_actual': '43.6',
#      'overs_unique': '43.06',
#      'players': 'Pope to McDermott',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': '',
#      'event': 'no run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '44',
#      'overs_actual': '43.5',
#      'overs_unique': '43.05',
#      'players': 'Pope to McDermott',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': '',
#      'event': 'no run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '44',
#      'overs_actual': '43.4',
#      'overs_unique': '43.04',
#      'players': 'Pope to McDermott',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': '',
#      'event': 'no run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '44',
#      'overs_actual': '43.3',
#      'overs_unique': '43.03',
#      'players': 'Pope to McDermott',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': '',
#      'event': 'no run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '44',
#      'overs_actual': '43.2',
#      'overs_unique': '43.02',
#      'players': 'Pope to McDermott',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': 'JC Silk run out 27 (28b 2x4 0x6) SR: 96.42',
#      'event': 'OUT',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '44',
#      'overs_actual': '43.1',
#      'overs_unique': '43.01',
#      'players': 'Pope to Silk',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''}],
#    'batsman': [{'balls_faced': '135',
#      'fours': '6',
#      'live_current_name': 'striker',
#      'player_id': '70392',
#      'runs': '99',
#      'sixes': '1'},
#     {'balls_faced': '0',
#      'fours': '0',
#      'live_current_name': 'non-striker',
#      'player_id': '35384',
#      'runs': '0',
#      'sixes': '0'}],
#    'bowler': [{'conceded': '39',
#      'live_current_name': 'current bowler',
#      'maidens': '0',
#      'overs': '6.0',
#      'player_id': '96336',
#      'wickets': '0'},
#     {'conceded': '52',
#      'live_current_name': 'previous bowler',
#      'maidens': '0',
#      'overs': '10.0',
#      'player_id': '66190',
#      'wickets': '1'}],
#    'event_string': '1 run',
#    'innings_number': '2',
#    'over_complete': '1',
#    'over_number': '44',
#    'required_string': '13 runs required from 36 balls, RR: 4.90, RRR: 2.16',
#    'runs': '216',
#    'team_id': '611',
#    'wickets': '3'},
#   {'ball': [{'comms_id': '',
#      'dismissal': '',
#      'event': '1 run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '43',
#      'overs_actual': '42.6',
#      'overs_unique': '42.06',
#      'players': 'Head to Silk',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': '',
#      'event': '1 run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '43',
#      'overs_actual': '42.5',
#      'overs_unique': '42.05',
#      'players': 'Head to McDermott',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': '',
#      'event': '1 run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '43',
#      'overs_actual': '42.4',
#      'overs_unique': '42.04',
#      'players': 'Head to Silk',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': '',
#      'event': 'no run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '43',
#      'overs_actual': '42.3',
#      'overs_unique': '42.03',
#      'players': 'Head to Silk',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': '',
#      'event': '1 run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '43',
#      'overs_actual': '42.2',
#      'overs_unique': '42.02',
#      'players': 'Head to McDermott',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': '',
#      'event': '1 run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '43',
#      'overs_actual': '42.1',
#      'overs_unique': '42.01',
#      'players': 'Head to Silk',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''}],
#    'batsman': [{'balls_faced': '27',
#      'fours': '2',
#      'live_current_name': 'striker',
#      'player_id': '61749',
#      'runs': '27',
#      'sixes': '0'},
#     {'balls_faced': '130',
#      'fours': '6',
#      'live_current_name': 'non-striker',
#      'player_id': '70392',
#      'runs': '98',
#      'sixes': '1'}],
#    'bowler': [{'conceded': '52',
#      'live_current_name': 'current bowler',
#      'maidens': '0',
#      'overs': '10.0',
#      'player_id': '66190',
#      'wickets': '1'},
#     {'conceded': '38',
#      'live_current_name': 'previous bowler',
#      'maidens': '0',
#      'overs': '5.0',
#      'player_id': '96336',
#      'wickets': '0'}],
#    'event_string': '5 runs',
#    'innings_number': '2',
#    'over_complete': '1',
#    'over_number': '43',
#    'required_string': '14 runs required from 42 balls, RR: 5.00, RRR: 2.00',
#    'runs': '215',
#    'team_id': '611',
#    'wickets': '2'},
#   {'ball': [{'comms_id': '',
#      'dismissal': '',
#      'event': '1 run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '42',
#      'overs_actual': '41.6',
#      'overs_unique': '41.06',
#      'players': 'Pope to Silk',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': '',
#      'event': '1 run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '42',
#      'overs_actual': '41.5',
#      'overs_unique': '41.05',
#      'players': 'Pope to McDermott',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''},
#     {'comms_id': '',
#      'dismissal': '',
#      'event': '1 run',
#      'innings_number': '2',
#      'is_tweet': '',
#      'over_number': '42',
#      'overs_actual': '41.4',
#      'overs_unique': '41.04',
#      'players': 'Pope to Silk',
#      'speed_kph': '',
#      'speed_mph': '',
#      'text': ''}],
#    'batsman': [{'balls_faced': '23',
#      'fours': '2',
#      'live_current_name': 'striker',
#      'player_id': '61749',
#      'runs': '24',
#      'sixes': '0'},
#     {'balls_faced': '128',
#      'fours': '6',
#      'live_current_name': 'non-striker',
#      'player_id': '70392',
#      'runs': '96',
#      'sixes': '1'}],
#    'bowler': [{'conceded': '38',
#      'live_current_name': 'current bowler',
#      'maidens': '0',
#      'overs': '5.0',
#      'player_id': '96336',
#      'wickets': '0'},
#     {'conceded': '47',
#      'live_current_name': 'previous bowler',
#      'maidens': '0',
#      'overs': '9.0',
#      'player_id': '66190',
#      'wickets': '1'}],
#    'event_string': '9 runs',
#    'innings_number': '2',
#    'over_complete': '1',
#    'over_number': '42',
#    'required_string': '19 runs required from 48 balls, RR: 5.00, RRR: 2.37',
#    'runs': '210',
#    'team_id': '611',
#    'wickets': '2'}],
#  'description': 'The Marsh Cup, 8th Match: South Australia v Tasmania at Adelaide, Sep 29, 2019',
#  'innings': [{'ball_limit': '300',
#    'balls': '300',
#    'batted': '1',
#    'batting_team_id': '571',
#    'bowling_team_id': '611',
#    'bpo': '6',
#    'byes': '0',
#    'event': '0',
#    'event_name': None,
#    'extras': '17',
#    'innings_number': '1',
#    'innings_numth': '1st',
#    'lead': '228',
#    'legbyes': '1',
#    'live_current': '0',
#    'live_current_name': None,
#    'minutes': None,
#    'noballs': '2',
#    'old_penalty_or_bonus': '0',
#    'over_limit': '50.0',
#    'over_limit_run_rate': '4.56',
#    'over_split_limit': '0.0',
#    'overs': '50.0',
#    'overs_docked': '0',
#    'penalties': '0',
#    'penalties_field_end': '0',
#    'penalties_field_start': '0',
#    'run_rate': '4.56',
#    'runs': '228',
#    'target': '0',
#    'wickets': '9',
#    'wides': '14'},
#   {'ball_limit': '300',
#    'balls': '278',
#    'batted': '1',
#    'batting_team_id': '611',
#    'bowling_team_id': '571',
#    'bpo': '6',
#    'byes': '0',
#    'event': '0',
#    'event_name': None,
#    'extras': '7',
#    'innings_number': '2',
#    'innings_numth': '1st',
#    'lead': '1',
#    'legbyes': '1',
#    'live_current': '1',
#    'live_current_name': 'current innings',
#    'minutes': None,
#    'noballs': '0',
#    'old_penalty_or_bonus': '0',
#    'over_limit': '50.0',
#    'over_limit_run_rate': '4.58',
#    'over_split_limit': '0.0',
#    'overs': '46.2',
#    'overs_docked': '0',
#    'penalties': '0',
#    'penalties_field_end': '0',
#    'penalties_field_start': '0',
#    'run_rate': '4.94',
#    'runs': '229',
#    'target': '229',
#    'wickets': '5',
#    'wides': '6'}],
#  'live': {'batting': [{'balls_faced': '140',
#     'batting_averages': {'batting_average': '57.20',
#      'batting_strike_rate': '79.07',
#      'class_card': 'List A',
#      'high_score': ' 117',
#      'hundreds': '3',
#      'innings': '17',
#      'matches': '17',
#      'player_id': '70392',
#      'runs': '858'},
#     'batting_averages_series': {'batting_average': '103.00',
#      'batting_strike_rate': '70.54',
#      'high_score': '103*',
#      'hundreds': '1',
#      'innings': '3',
#      'matches': '3',
#      'player_id': '70392',
#      'runs': '206',
#      'series_type_name': 'tournament'},
#     'batting_position': '1',
#     'batting_pvp': {'balls': '25', 'bowler_player_id': '70473', 'runs': '18'},
#     'batting_recent': {'balls': '14',
#      'over_span': '5',
#      'player_id': '70392',
#      'runs': '9'},
#     'fours': '6',
#     'innings_number': '2',
#     'live_current': '1',
#     'live_current_name': 'striker',
#     'minutes': '',
#     'player_id': '70392',
#     'runs': '103',
#     'sixes': '1',
#     'strike_rate': '73.57',
#     'team_id': '611'},
#    {'balls_faced': '3',
#     'batting_averages': {'batting_average': '29.45',
#      'batting_strike_rate': '91.13',
#      'class_card': 'List A',
#      'high_score': ' 116',
#      'hundreds': '1',
#      'innings': '97',
#      'matches': '124',
#      'player_id': '50483',
#      'runs': '1944'},
#     'batting_averages_series': {'batting_average': '4.00',
#      'batting_strike_rate': '50.00',
#      'high_score': '   5',
#      'hundreds': '0',
#      'innings': '3',
#      'matches': '3',
#      'player_id': '50483',
#      'runs': '8',
#      'series_type_name': 'tournament'},
#     'batting_position': '7',
#     'batting_pvp': {'balls': '1', 'bowler_player_id': '70473', 'runs': '1'},
#     'batting_recent': {'balls': '3',
#      'over_span': '5',
#      'player_id': '50483',
#      'runs': '2'},
#     'fours': '0',
#     'innings_number': '2',
#     'live_current': '2',
#     'live_current_name': 'non-striker',
#     'minutes': '',
#     'player_id': '50483',
#     'runs': '2',
#     'sixes': '0',
#     'strike_rate': '66.66',
#     'team_id': '611'}],
#   'bowling': [{'bowling_averages': {'bbi': '  4/49',
#      'bowling_average': '29.90',
#      'class_card': 'List A',
#      'economy_rate': '5.34',
#      'five_wickets': '0',
#      'matches': '22',
#      'overs': '179.0',
#      'player_id': '70473',
#      'wickets': '32'},
#     'bowling_averages_series': {'bbi': '  1/17',
#      'bowling_average': '26.00',
#      'economy_rate': '3.86',
#      'five_wickets': '0',
#      'matches': '3',
#      'player_id': '70473',
#      'series_type_name': 'tournament',
#      'wickets': '3'},
#     'bowling_scoring': {'dots': '28',
#      'fours': '1',
#      'player_id': '70473',
#      'sixes': '1'},
#     'bowling_spell': {},
#     'conceded': '42',
#     'economy_rate': '4.50',
#     'innings_number': '2',
#     'live_current': '1',
#     'live_current_name': 'current bowler',
#     'maidens': '0',
#     'noballs': '0',
#     'overs': '9.2',
#     'player_id': '70473',
#     'team_id': '571',
#     'wickets': '1',
#     'wides': '3'},
#    {'bowling_averages': {'bbi': '  1/43',
#      'bowling_average': '45.50',
#      'class_card': 'List A',
#      'economy_rate': '6.50',
#      'five_wickets': '0',
#      'matches': '2',
#      'overs': '14.0',
#      'player_id': '96336',
#      'wickets': '2'},
#     'bowling_averages_series': {'bbi': '  1/43',
#      'bowling_average': '45.50',
#      'economy_rate': '6.50',
#      'five_wickets': '0',
#      'matches': '2',
#      'player_id': '96336',
#      'series_type_name': 'tournament',
#      'wickets': '2'},
#     'bowling_scoring': {'dots': '18',
#      'fours': '4',
#      'player_id': '96336',
#      'sixes': '1'},
#     'bowling_spell': {},
#     'conceded': '43',
#     'economy_rate': '6.14',
#     'innings_number': '2',
#     'live_current': '2',
#     'live_current_name': 'previous bowler',
#     'maidens': '0',
#     'noballs': '0',
#     'overs': '7.0',
#     'player_id': '96336',
#     'team_id': '571',
#     'wickets': '1',
#     'wides': '1'}],
#   'break': '',
#   'field_restrict': [],
#   'fow': [{'fow_order': '5',
#     'fow_overs': '46.2',
#     'fow_runs': '229',
#     'fow_wickets': '5',
#     'innings_number': '2',
#     'live_current': '1',
#     'live_current_name': 'current partnership',
#     'opposition_id': '571',
#     'out_player': {},
#     'partnership_overs': '0.5',
#     'partnership_rate': '6.00',
#     'partnership_runs': '5',
#     'partnership_wicket': '6',
#     'partnership_wicket_name': '6th',
#     'player': [{'fow_runs': '', 'partnership_runs': '', 'player_id': ''},
#      {'fow_runs': '', 'partnership_runs': '', 'player_id': ''}],
#     'player_id': None,
#     'team_id': '611'},
#    {'fow_order': '4',
#     'fow_overs': '45.3',
#     'fow_runs': '224',
#     'fow_wickets': '5',
#     'innings_number': '2',
#     'live_current': '2',
#     'live_current_name': 'last wicket',
#     'opposition_id': '571',
#     'out_player': {'balls_faced': '1',
#      'dismissal_string': 'c Head b Pope',
#      'fours': '0',
#      'minutes': '',
#      'player_id': '58730',
#      'runs': '0',
#      'sixes': '0',
#      'strike_rate': '0.00'},
#     'partnership_overs': '0.3',
#     'partnership_rate': '2.00',
#     'partnership_runs': '1',
#     'partnership_wicket': '5',
#     'partnership_wicket_name': '5th',
#     'player': [{'fow_runs': '', 'partnership_runs': '', 'player_id': ''},
#      {'fow_runs': '', 'partnership_runs': '', 'player_id': ''}],
#     'player_id': '58730',
#     'team_id': '611'}],
#   'innings': {'ball_limit': '300',
#    'balls': '278',
#    'batted': '1',
#    'batting_team_id': '611',
#    'bowling_team_id': '571',
#    'bpo': '6',
#    'event': '0',
#    'event_name': None,
#    'innings_number': '2',
#    'lead': '1',
#    'live_current': '1',
#    'live_current_name': 'current innings',
#    'over_limit': '50.0',
#    'over_limit_run_rate': '4.58',
#    'over_split_limit': '0.0',
#    'overs': '46.2',
#    'remaining_balls': '22',
#    'remaining_overs': '3.4',
#    'remaining_wickets': '5',
#    'required_run_rate': None,
#    'run_rate': '4.94',
#    'runs': '229',
#    'target': '229',
#    'team_id': '611',
#    'wickets': '5'},
#   'innings_recent': [{'balls': '30',
#     'innings_number': '2',
#     'over_span': '5',
#     'run_rate': '4.60',
#     'runs': '23',
#     'wickets': '3'}],
#   'recent_overs': [[{'ball': 'W',
#      'ball_number': '1',
#      'extras': '',
#      'over_number': '44'},
#     {'ball': '&bull;', 'ball_number': '2', 'extras': '', 'over_number': '44'},
#     {'ball': '&bull;', 'ball_number': '3', 'extras': '', 'over_number': '44'},
#     {'ball': '&bull;', 'ball_number': '4', 'extras': '', 'over_number': '44'},
#     {'ball': '&bull;', 'ball_number': '5', 'extras': '', 'over_number': '44'},
#     {'ball': '1', 'ball_number': '6', 'extras': '', 'over_number': '44'}],
#    [{'ball': '1', 'ball_number': '1', 'extras': '', 'over_number': '45'},
#     {'ball': '&bull;', 'ball_number': '2', 'extras': '', 'over_number': '45'},
#     {'ball': '&bull;', 'ball_number': '3', 'extras': '', 'over_number': '45'},
#     {'ball': '&bull;', 'ball_number': '4', 'extras': '', 'over_number': '45'},
#     {'ball': '6', 'ball_number': '5', 'extras': '', 'over_number': '45'},
#     {'ball': 'W', 'ball_number': '6', 'extras': '', 'over_number': '45'}],
#    [{'ball': '&bull;', 'ball_number': '1', 'extras': '', 'over_number': '46'},
#     {'ball': '1', 'ball_number': '2', 'extras': '', 'over_number': '46'},
#     {'ball': 'W', 'ball_number': '3', 'extras': '', 'over_number': '46'},
#     {'ball': '&bull;', 'ball_number': '4', 'extras': '', 'over_number': '46'},
#     {'ball': '1', 'ball_number': '5', 'extras': 'wd', 'over_number': '46'},
#     {'ball': '1', 'ball_number': '6', 'extras': '', 'over_number': '46'},
#     {'ball': '1', 'ball_number': '7', 'extras': '', 'over_number': '46'}],
#    [{'ball': '1', 'ball_number': '1', 'extras': '', 'over_number': '47'},
#     {'ball': '1', 'ball_number': '2', 'extras': '', 'over_number': '47'}]],
#   'review': [],
#   'status': 'Tasmania won by 5 wickets (with 22 balls remaining)'},
#  'live_clipper': {},
#  'live_video': {},
#  'match': {'actual_days': '1',
#   'adjusted': '0',
#   'amount': '5',
#   'amount_balls': '22',
#   'amount_name': 'wickets',
#   'amount_type': '3',
#   'away_team_id': '611',
#   'ballbyball_source': '',
#   'batting_first_team_id': '571',
#   'bitly_hash': '',
#   'cancelled_match': 'N',
#   'cms_match_title': '8th Match',
#   'commentary_source': 'dougie',
#   'continent_id': '5',
#   'continent_name': 'Oceania',
#   'country_abbreviation': 'AUS',
#   'country_filename': 'AUS',
#   'country_id': '2',
#   'country_name': 'Australia',
#   'current_summary': 'Tasmania 229/5 (46.2 ov, BR McDermott 103*, JP Faulkner 2*, C Valente 1/42) - Match over',
#   'current_summary_abbreviation': 'TAS 229/5 (46.2 ov, BR McDermott 103*, JP Faulkner 2*, C Valente 1/42) - Match over',
#   'date': 'Sep 29, 2019',
#   'date_string': '29 September 2019',
#   'days_extended': '0',
#   'end_date': 'Sep 29, 2019',
#   'end_date_raw': '2019-09-29',
#   'floodlit': '1',
#   'floodlit_name': 'day match',
#   'followon': '0',
#   'general_class_card': 'List A',
#   'general_class_id': '5',
#   'general_class_name': 'List A matches',
#   'general_number': '',
#   'general_valid': '1',
#   'gmt_difference': '+0930',
#   'ground_id': '1343',
#   'ground_latitude': '-34.922619',
#   'ground_longitude': '138.583176',
#   'ground_name': 'Karen Rolton Oval, Adelaide',
#   'ground_object_id': '56300',
#   'ground_small_name': 'Adelaide',
#   'hawkeye_source': '',
#   'head2head_source': 'dougie',
#   'home_team_id': '571',
#   'hours_string': '10.00 start, First Session 10.00-13.30, Interval 13.30-14.15, Second Session 14.15-17.45',
#   'international_class_card': '',
#   'international_class_id': '0',
#   'international_class_name': '',
#   'international_number': '',
#   'international_valid': '0',
#   'legacy_url': '/db/ARCHIVE/2019-20/AUS_LOCAL/TMARSH-CUP/SCORECARDS/SOA_TAS_TMARSH-CUP_29SEP2019',
#   'live_commentator': '',
#   'live_companion': 'N',
#   'live_day_number': '1',
#   'live_innings_number': '2',
#   'live_match': 'Y',
#   'live_note': '',
#   'live_overs_remaining': '0.0',
#   'live_overs_unique': '46.02',
#   'live_scorer': '',
#   'live_session_number': '0',
#   'live_state': '',
#   'match_clock': '',
#   'match_day_countdown': '0',
#   'match_minute_countdown': '',
#   'match_path': '',
#   'match_status': 'current',
#   'neutral_match': '0',
#   'next_datetime_gmt': '2019-09-29 00:30:00',
#   'next_datetime_local': '2019-09-29 10:00:00',
#   'player_rating': 'N',
#   'present_date_gmt': '2019-09-29',
#   'present_date_local': '2019-09-29',
#   'present_datetime_gmt': '2019-09-29 09:21:00',
#   'present_datetime_local': '2019-09-29 18:51:00',
#   'present_time_gmt': '09:21:00',
#   'present_time_local': '18:51:00',
#   'rain_rule': '0',
#   'rain_rule_name': '',
#   'rating_promo': '',
#   'reduced': '0',
#   'reserve_days_used': '0',
#   'result': '1',
#   'result_name': 'won',
#   'result_short_name': 'won',
#   'schedule_note': '',
#   'scheduled_days': '1',
#   'scheduled_innings': '1',
#   'scheduled_overs': '50',
#   'scorecard_source': 'dougie',
#   'scribble_id': '0',
#   'season': '2019/20',
#   'site_id': '1',
#   'site_name': 'Global',
#   'start_date': 'Sep 29, 2019',
#   'start_date_gmt_offset': '0',
#   'start_date_raw': '2019-09-29',
#   'start_datetime_gmt': '2019-09-29 00:30:00',
#   'start_datetime_gmt_raw': '2019-09-29 00:30:00',
#   'start_datetime_local': '2019-09-29 10:00:00',
#   'start_time_gmt': '00:30:00',
#   'start_time_local': '10:00:00',
#   'team1_abbreviation': 'SOA',
#   'team1_class_id': '4',
#   'team1_country_id': '2',
#   'team1_filename': 'SOA',
#   'team1_id': '571',
#   'team1_logo_alt_id': '',
#   'team1_logo_espncdn': 'N',
#   'team1_logo_object_id': '0',
#   'team1_name': 'South Australia',
#   'team1_object_id': '520',
#   'team1_short_name': 'South Aust',
#   'team2_abbreviation': 'TAS',
#   'team2_class_id': '4',
#   'team2_country_id': '2',
#   'team2_filename': 'TAS',
#   'team2_id': '611',
#   'team2_logo_alt_id': '',
#   'team2_logo_espncdn': 'N',
#   'team2_logo_object_id': '0',
#   'team2_name': 'Tasmania',
#   'team2_object_id': '560',
#   'team2_short_name': 'Tasmania',
#   'tiebreaker_name': '',
#   'tiebreaker_team_id': '0',
#   'tiebreaker_type': '0',
#   'time_zone': 'Australia/Adelaide',
#   'toss_choice_team_id': '0',
#   'toss_decision': '1',
#   'toss_decision_name': 'bat',
#   'toss_winner_team_id': '571',
#   'town_aka': '',
#   'town_area': 'South Australia',
#   'town_id': '2',
#   'town_name': 'Adelaide',
#   'tz_short_name': 'ACST',
#   'url_component': 'ci',
#   'watch_espn_id': '0',
#   'weather_location_code': 'ASXX0001',
#   'winner_team_id': '611'},
#  'match_card': '<li><div class="score-table-box"><table width="100%" class="score-stats-table"><caption>To bat</caption><tr class="tr-heading"><th></th><th scope="col" class="text-left">Player</th><th scope="col">Mat</th><th scope="col">Runs</th><th scope="col">HS</th><th scope="col">Ave</th><th scope="col">100</th></tr><tr><td>8.</td><td class="text-left"><a href="/ci/content/player/499660.html" target="_blank" title="view the player profile for Gurinder Sandhu">GS Sandhu</a></td><td>54</td><td>180</td><td>21*</td><td>12.00</td><td>0</td></tr><tr><td>9.</td><td class="text-left"><a href="/ci/content/player/826915.html" title="view the player profile for Nathan Ellis" target="_blank">NT Ellis</a></td><td>3</td><td>1</td><td>1</td><td>0.50</td><td>0</td></tr><tr><td>10.</td><td class="text-left"><a href="/ci/content/player/215152.html" target="_blank" title="view the player profile for Jackson Bird">JM Bird</a></td><td>31</td><td>100</td><td>26</td><td>12.50</td><td>0</td></tr><tr><td>11.</td><td class="text-left"><a href="/ci/content/player/961713.html" title="view the player profile for Riley Meredith" target="_blank">RP Meredith</a></td><td>16</td><td>11</td><td>3*</td><td>5.50</td><td>0</td></tr></table></div></li><li><div class="score-table-box"><table width="100%" class="score-stats-table"><tr class="tr-heading"><th scope="col" colspan="2" class="text-left">Batting</th><th scope="col">R</th><th scope="col">B</th><th scope="col">4</th><th scope="col">6</th></tr><tr><td class="text-left"><a href="/ci/content/player/603410.html" target="_blank" title="view the player profile for Ben McDermott">BR McDermott</a></td><td class="text-left">not out</td><td>103</td><td>140</td><td>6</td><td>1</td></tr><tr><td class="text-left"><a href="/ci/content/player/834741.html" target="_blank" title="view the player profile for Caleb Jewell">CP Jewell</a></td><td class="text-left">caught</td><td>64</td><td>77</td><td>8</td><td>0</td></tr><tr><td class="text-left"><a href="/ci/content/player/230193.html" title="view the player profile for Matthew Wade" target="_blank">MS Wade</a></td><td class="text-left">caught</td><td>20</td><td>24</td><td>2</td><td>0</td></tr><tr><td class="text-left"><a href="/ci/content/player/437669.html" target="_blank" title="view the player profile for Jordan Silk">JC Silk</a></td><td class="text-left">run out</td><td>27</td><td>28</td><td>2</td><td>0</td></tr><tr><td class="text-left"><a href="/ci/content/player/4451.html" target="_blank" title="view the player profile for George Bailey">GJ Bailey</a></td><td class="text-left">bowled</td><td>6</td><td>5</td><td>0</td><td>1</td></tr><tr><td class="text-left"><a href="/ci/content/player/381329.html" target="_blank" title="view the player profile for Beau Webster">BJ Webster</a></td><td class="text-left">caught</td><td>0</td><td>1</td><td>0</td><td>0</td></tr><tr><td class="text-left"><a href="/ci/content/player/270484.html" target="_blank" title="view the player profile for James Faulkner">JP Faulkner</a></td><td class="text-left">not out</td><td>2</td><td>3</td><td>0</td><td>0</td></tr><tr><td class="text-left"><a href="/ci/content/player/499660.html" target="_blank" title="view the player profile for Gurinder Sandhu">GS Sandhu</a></td><td class="text-left"></td><td></td><td></td><td></td><td></td></tr><tr><td class="text-left"><a href="/ci/content/player/826915.html" title="view the player profile for Nathan Ellis" target="_blank">NT Ellis</a></td><td class="text-left"></td><td></td><td></td><td></td><td></td></tr><tr><td class="text-left"><a href="/ci/content/player/215152.html" target="_blank" title="view the player profile for Jackson Bird">JM Bird</a></td><td class="text-left"></td><td></td><td></td><td></td><td></td></tr><tr><td class="text-left"><a href="/ci/content/player/961713.html" title="view the player profile for Riley Meredith" target="_blank">RP Meredith</a></td><td class="text-left"></td><td></td><td></td><td></td><td></td></tr><tr><td class="text-le ...
#  'middle_column': '',
#  'official': [{'age_days': '182',
#    'age_years': '51',
#    'alpha_name': 'CLOSE,DR',
#    'batting_hand': 'unknown hand',
#    'bowling_hand': 'unknown arm',
#    'bowling_pacespin': 'mixture/unknown',
#    'card_long': 'DR Close',
#    'card_qualifier': '',
#    'card_short': 'DR Close',
#    'dob': '1968-03-31',
#    'known_as': 'Darren Close',
#    'mobile_name': 'Close',
#    'object_id': '4888',
#    'player_id': '48260',
#    'player_type': '2',
#    'player_type_name': 'umpire',
#    'popular_name': 'Close',
#    'portrait_alt_id': '',
#    'portrait_object_id': '0',
#    'status_id': '3',
#    'team_abbreviation': None,
#    'team_id': '0',
#    'team_name': None,
#    'team_short_name': None},
#   {'age_days': '62',
#    'age_years': '53',
#    'alpha_name': 'FRY,SD',
#    'batting_hand': 'unknown hand',
#    'bowling_hand': 'unknown arm',
#    'bowling_pacespin': 'mixture/unknown',
#    'card_long': 'SD Fry',
#    'card_qualifier': '',
#    'card_short': 'SD Fry',
#    'dob': '1966-07-29',
#    'known_as': 'Simon Fry',
#    'mobile_name': 'Fry',
#    'object_id': '5341',
#    'player_id': '45391',
#    'player_type': '2',
#    'player_type_name': 'umpire',
#    'popular_name': 'Fry',
#    'portrait_alt_id': '1',
#    'portrait_object_id': '954009',
#    'status_id': '3',
#    'team_abbreviation': None,
#    'team_id': '0',
#    'team_name': None,
#    'team_short_name': None},
#   {'age_days': '63',
#    'age_years': '64',
#    'alpha_name': 'MARSHALL,PL',
#    'batting_hand': 'unknown hand',
#    'bowling_hand': 'unknown arm',
#    'bowling_pacespin': 'mixture/unknown',
#    'card_long': 'PL Marshall',
#    'card_qualifier': '',
#    'card_short': 'PL Marshall',
#    'dob': '1955-07-28',
#    'known_as': 'Peter Marshall',
#    'mobile_name': 'Marshall',
#    'object_id': '431847',
#    'player_id': '61407',
#    'player_type': '4',
#    'player_type_name': 'referee',
#    'popular_name': 'Marshall',
#    'portrait_alt_id': '',
#    'portrait_object_id': '0',
#    'status_id': '3',
#    'team_abbreviation': None,
#    'team_id': '0',
#    'team_name': None,
#    'team_short_name': None}],
#  'other_scores': {'domestic': [{'object_id': '1199401',
#     'start_time': '10:00&nbsp;local | 05:00&nbsp;GMT | 07:00&nbsp;CEST',
#     'team1_desc': ' 338/5',
#     'team1_name': 'CPNJB',
#     'team2_desc': '',
#     'team2_name': 'Baluc',
#     'url': '/ci/engine/match/1199401.html'},
#    {'object_id': '1199403',
#     'start_time': '10:00&nbsp;local | 05:00&nbsp;GMT | 07:00&nbsp;CEST',
#     'team1_desc': ' 126/0',
#     'team1_name': 'KPK',
#     'team2_desc': '',
#     'team2_name': 'SPNJB',
#     'url': '/ci/engine/match/1199403.html'},
#    {'object_id': '1199402',
#     'start_time': '10:00&nbsp;local | 05:00&nbsp;GMT | 07:00&nbsp;CEST',
#     'team1_desc': ' 86/3',
#     'team1_name': 'NORTH',
#     'team2_desc': '',
#     'team2_name': 'Sindh',
#     'url': '/ci/engine/match/1199402.html'},
#    {'object_id': '1196098',
#     'result': 'Queensland won by 154 runs',
#     'start_time': '10:00&nbsp;local | 00:00&nbsp;GMT | 02:00&nbsp;CEST',
#     'team1_desc': ' 322/9',
#     'team1_name': 'QLD',
#     'team2_desc': ' 168 (39.5/50&nbsp;ov)',
#     'team2_name': 'VIC',
#     'url': '/ci/engine/match/1196098.html'},
#    {'object_id': '1196099',
#     'result': 'Tasmania won by 5 wickets (with 22 balls remaining)',
#     'start_time': '10:00&nbsp;local | 00:30&nbsp;GMT | 02:30&nbsp;CEST',
#     'team1_desc': ' 228/9',
#     'team1_name': 'SOA',
#     'team2_desc': ' 229/5 (46.2/50&nbsp;ov)',
#     'team2_name': 'TAS',
#     'url': '/ci/engine/match/1196099.html'},
#    {'object_id': '1200635',
#     'start_time': '09:00&nbsp;local | 03:30&nbsp;GMT | 05:30&nbsp;CEST',
#     'team1_desc': ' 268/9',
#     'team1_name': 'CGARH',
#     'team2_desc': ' 68/1 (20/50&nbsp;ov)',
#     'team2_name': 'AP',
#     'url': '/ci/engine/match/1200635.html'},
#    {'object_id': '1200769',
#     'result': 'Match abandoned without a ball bowled',
#     'start_time': '09:00&nbsp;local | 03:30&nbsp;GMT | 05:30&nbsp;CEST',
#     'team1_desc': '',
#     'team1_name': 'BRODA',
#     'team2_desc': '',
#     'team2_name': 'PNJB',
#     'url': '/ci/engine/match/1200769.html'},
#    {'object_id': '1200765',
#     'result': 'Match abandoned without a ball bowled',
#     'start_time': '09:00&nbsp;local | 03:30&nbsp;GMT | 05:30&nbsp;CEST',
#     'team1_desc': '',
#     'team1_name': 'CHGRH',
#     'team2_desc': '',
#     'team2_name': 'Manipur',
#     'url': '/ci/engine/match/1200765.html'},
#    {'object_id': '1200768',
#     'start_time': '09:00&nbsp;local | 03:30&nbsp;GMT | 05:30&nbsp;CEST',
#     'team1_desc': ' 266/8',
#     'team1_name': 'GOA',
#     'team2_desc': ' 37/2 (10/50&nbsp;ov)',
#     'team2_name': 'JKAND',
#     'url': '/ci/engine/match/1200768.html'},
#    {'object_id': '1200771',
#     'result': 'Match abandoned without a ball bowled',
#     'start_time': '09:00&nbsp;local | 03:30&nbsp;GMT | 05:30&nbsp;CEST',
#     'team1_desc': '',
#     'team1_name': 'HRYNA',
#     'team2_desc': '',
#     'team2_name': 'UP',
#     'url': '/ci/engine/match/1200771.html'},
#    {'object_id': '1200638',
#     'result': 'Match abandoned without a ball bowled',
#     'start_time': '09:00&nbsp;local | 03:30&nbsp;GMT | 05:30&nbsp;CEST',
#     'team1_desc': '',
#     'team1_name': 'HP',
#     'team2_desc': '',
#     'team2_name': 'MAHA',
#     'url': '/ci/engine/match/1200638.html'},
#    {'object_id': '1200766',
#     'start_time': '09:00&nbsp;local | 03:30&nbsp;GMT | 05:30&nbsp;CEST',
#     'team1_desc': ' 226/9',
#     'team1_name': 'KER',
#     'team2_desc': ' 25/4 (10/50&nbsp;ov)',
#     'team2_name': 'HYD',
#     'url': '/ci/engine/match/1200766.html'},
#    {'object_id': '1200692',
#     'result': 'Match abandoned without a ball bowled',
#     'start_time': '09:00&nbsp;local | 03:30&nbsp;GMT | 05:30&nbsp;CEST',
#     'team1_desc': '',
#     'team1_name': 'MIZOR',
#     'team2_desc': '',
#     'team2_name': 'NAGA',
#     'url': '/ci/engine/match/1200692.html'},
#    {'object_id': '1185862',
#     'start_time': '18:00&nbsp;local | 22:00&nbsp;GMT | 00:00&nbsp;CEST&nbsp;1d',
#     'team1_desc': '',
#     'team1_name': 'BT',
#     'team2_desc': '',
#     'team2_name': 'ZOUKS',
#     'url': '/ci/engine/match/1185862.html'},
#    {'object_id': '1197541',
#     'result': 'Hong Kong CC won by 6 wickets (with 58 balls remaining)',
#     'start_time': '13:30&nbsp;local | 05:30&nbsp;GMT | 07:30&nbsp;CEST',
#     'team1_desc': ' 67',
#     'team1_name': 'USRC',
#     'team2_desc': ' 69/4 (10.2/20&nbsp;ov)',
#     'team2_name': 'HkgCC',
#     'url': '/ci/engine/match/1197541.html'},
#    {'object_id': '1197542',
#     'start_time': '14:00&nbsp;local | 06:00&nbsp;GMT | 08:00&nbsp;CEST',
#     'team1_desc': ' 140',
#     'team1_name': 'KowCC',
#     'team2_desc': ' 143/9 (19.4/20&nbsp;ov)',
#     'team2_name': 'PAHKG',
#     'url': '/ci/engine/match/1197542.html'}],
#   'international': [{'object_id': '1201682',
#     'start_time': '19:30&nbsp;local | 11:30&nbsp;GMT | 13:30&nbsp;CEST',
#     'team1_desc': '',
#     'team1_name': 'SIN',
#     'team2_desc': '',
#     'team2_name': 'ZIM',
#     'url': '/ci/engine/match/1201682.html'},
#    {'object_id': '1202007',
#     'result': 'Vanuatu won by 17 runs',
#     'start_time': '10:00&nbsp;local | 02:00&nbsp;GMT | 04:00&nbsp;CEST',
#     'team1_desc': ' 151/5',
#     'team1_name': 'VAN',
#     'team2_desc': ' 134/9 (20&nbsp;ov)',
#     'team2_name': 'MAL',
#     'url': '/ci/engine/match/1202007.html'},
#    {'object_id': '1183510',
#     'result': 'AUS Women won by 41 runs',
#     'start_time': '14:40&nbsp;local | 04:40&nbsp;GMT | 06:40&nbsp;CEST',
#     'team1_desc': ' 217/4',
#     'team1_name': 'AUS-W',
#     'team2_desc': ' 176/7 (20&nbsp;ov)',
#     'team2_name': 'SL-W',
#     'url': '/ci/engine/match/1183510.html'},
#    {'object_id': '1198480',
#     'start_time': '19:00&nbsp;local | 13:30&nbsp;GMT | 15:30&nbsp;CEST',
#     'team1_desc': '',
#     'team1_name': 'IND-W',
#     'team2_desc': '',
#     'team2_name': 'SA-W',
#     'url': '/ci/engine/match/1198480.html'}],
#   'others': [{'object_id': '1201025',
#     'start_time': '10:00&nbsp;local | 04:30&nbsp;GMT | 06:30&nbsp;CEST',
#     'team1_desc': '',
#     'team1_name': 'BAN-A',
#     'team2_desc': '',
#     'team2_name': 'SL-A',
#     'url': '/ci/engine/match/1201025.html'},
#    {'object_id': '1202033',
#     'result': "B'desh U19 won by 6 wickets (with 68 balls remaining)",
#     'start_time': '11:00&nbsp;local | 22:00&nbsp;GMT&nbsp;-1d | 00:00&nbsp;CEST',
#     'team1_desc': ' 176',
#     'team1_name': 'NZ19',
#     'team2_desc': ' 180/4 (38.4/50&nbsp;ov)',
#     'team2_name': 'BD19',
#     'url': '/ci/engine/match/1202033.html'}]},
#  'score_source': '0',
#  'series': [{'class_id': '5',
#    'class_name': 'List A',
#    'content_id': '13212',
#    'core_recreation_id': '8626',
#    'date': 'Sep-Nov 2019',
#    'end_date': '26 Nov 2019',
#    'end_date_raw': '2019-11-26',
#    'final_type_name': 'preliminary matches',
#    'group_title': '',
#    'major_trophy': '0',
#    'match_number': '8',
#    'match_title': '8th Match',
#    'match_type_name': None,
#    'multiformat_pointstable': 'N',
#    'number_of_hosts': '1',
#    'number_of_matches': '1',
#    'number_of_teams': '6',
#    'object_id': '1196059',
#    'points': '1',
#    'replayed_date': None,
#    'schedule_note': '',
#    'score_module_position': '0',
#    'season': '2019/20',
#    'series_abbreviation': None,
#    'series_category_id': '1',
#    'series_category_name': 'competition',
#    'series_filename': None,
#    'series_lead_abandoned': '0',
#    'series_lead_cancelled': '0',
#    'series_lead_how_won_name': None,
#    'series_lead_lost': '0',
#    'series_lead_result_name': None,
#    'series_lead_team_name': None,
#    'series_lead_total': '0',
#    'series_lead_type_name': None,
#    'series_lead_won': '0',
#    'series_long_description': 'in Australia',
#    'series_name': 'The Marsh Cup',
#    'series_short_name': 'The Marsh Cup',
#    'series_status': 'current',
#    'series_type_id': '3',
#    'series_type_name': 'tournament',
#    'site_id': '1',
#    'slug': 'marsh-one-day-cup',
#    'start_date': '21 Sep 2019',
#    'start_date_raw': '2019-09-21',
#    'team1_points': '0.000',
#    'team2_points': '3.000',
#    'teams': [{'host_team': '1',
#      'object_id': '2',
#      'primary_team': '0',
#      'series_id': '13212',
#      'series_result_name': None,
#      'site_id': '6',
#      'team_abbreviation': 'AUS',
#      'team_filename': 'AUS',
#      'team_id': '2',
#      'team_name': 'Australia',
#      'team_short_name': 'Australia',
#      'url_component': 'australia'},
#     {'host_team': '0',
#      'object_id': '387',
#      'primary_team': '1',
#      'series_id': '13212',
#      'series_result_name': None,
#      'site_id': '929',
#      'team_abbreviation': 'NSW',
#      'team_filename': 'NSW',
#      'team_id': '438',
#      'team_name': 'New South Wales',
#      'team_short_name': 'NSW',
#      'url_component': 'newsouthwales'},
#     {'host_team': '0',
#      'object_id': '459',
#      'primary_team': '1',
#      'series_id': '13212',
#      'series_result_name': None,
#      'site_id': '930',
#      'team_abbreviation': 'QLD',
#      'team_filename': 'QLD',
#      'team_id': '510',
#      'team_name': 'Queensland',
#      'team_short_name': 'Queensland',
#      'url_component': 'queensland'},
#     {'host_team': '0',
#      'object_id': '520',
#      'primary_team': '1',
#      'series_id': '13212',
#      'series_result_name': None,
#      'site_id': '931',
#      'team_abbreviation': 'SOA',
#      'team_filename': 'SOA',
#      'team_id': '571',
#      'team_name': 'South Australia',
#      'team_short_name': 'South Aust',
#      'url_component': 'southaustralia'},
#     {'host_team': '0',
#      'object_id': '560',
#      'primary_team': '1',
#      'series_id': '13212',
#      'series_result_name': None,
#      'site_id': '932',
#      'team_abbreviation': 'TAS',
#      'team_filename': 'TAS',
#      'team_id': '611',
#      'team_name': 'Tasmania',
#      'team_short_name': 'Tasmania',
#      'url_component': 'tasmania'},
#     {'host_team': '0',
#      'object_id': '584',
#      'primary_team': '1',
#      'series_id': '13212',
#      'series_result_name': None,
#      'site_id': '933',
#      'team_abbreviation': 'VIC',
#      'team_filename': 'VIC',
#      'team_id': '635',
#      'team_name': 'Victoria',
#      'team_short_name': 'Victoria',
#      'url_component': 'victoria'},
#     {'host_team': '0',
#      'object_id': '602',
#      'primary_team': '1',
#      'series_id': '13212',
#      'series_result_name': None,
#      'site_id': '934',
#      'team_abbreviation': 'WA',
#      'team_filename': 'WA',
#      'team_id': '653',
#      'team_name': 'Western Australia',
#      'team_short_name': 'West Aust',
#      'url_component': 'westernaustralia'}],
#    'tiebreaker_id': '1',
#    'tiebreaker_name': 'net run-rate',
#    'trophy_abbreviation': 'Aust DOD',
#    'trophy_class_id': '5',
#    'trophy_country_id': '2',
#    'trophy_id': '122',
#    'trophy_name': 'Australian Domestic One-Day Competition',
#    'trophy_short_name': 'Marsh One-Day Cup',
#    'url_component': 'ci'}],
#  'substitute': [{'age_days': '149',
#    'age_years': '24',
#    'alpha_name': 'NIELSEN,HJ',
#    'batting_hand': 'left-hand batsman',
#    'batting_style': 'lhb',
#    'batting_style_long': 'left-hand bat',
#    'bowling_hand': 'right-arm bowler',
#    'bowling_pacespin': 'spin bowler',
#    'bowling_style': 'ob',
#    'bowling_style_long': 'right-arm offbreak ',
#    'captain': '0',
#    'card_long': 'HJ Nielsen',
#    'card_qualifier': '',
#    'card_short': 'HJ Nielsen',
#    'dob': '1995-05-03',
#    'full_sub': '0',
#    'full_sub_innings': '0',
#    'full_sub_name': None,
#    'full_sub_overs': '0.0',
#    'full_sub_player_id': '0',
#    'keeper': '0',
#    'known_as': 'Harry Nielsen',
#    'mobile_name': 'Nielsen',
#    'object_id': '713195',
#    'player_id': '74933',
#    'player_primary_role': None,
#    'player_style_id': None,
#    'player_type': '5',
#    'player_type_name': 'sub fielder',
#    'popular_name': 'Nielsen',
#    'portrait_alt_id': '',
#    'portrait_object_id': '0',
#    'status_id': '3',
#    'team_abbreviation': 'SOA',
#    'team_id': '571',
#    'team_name': 'South Australia',
#    'team_short_name': 'South Aust'},
#   {'age_days': '134',
#    'age_years': '25',
#    'alpha_name': 'ROBINS,LJ',
#    'batting_hand': 'right-hand batsman',
#    'batting_style': 'rhb',
#    'batting_style_long': 'right-hand bat',
#    'bowling_hand': 'right-arm bowler',
#    'bowling_pacespin': 'pace bowler',
#    'bowling_style': 'rfm',
#    'bowling_style_long': 'right-arm fast-medium ',
#    'captain': '0',
#    'card_long': 'LJ Robins',
#    'card_qualifier': '',
#    'card_short': 'LJ Robins',
#    'dob': '1994-05-18',
#    'full_sub': '0',
#    'full_sub_innings': '0',
#    'full_sub_name': None,
#    'full_sub_overs': '0.0',
#    'full_sub_player_id': '0',
#    'keeper': '0',
#    'known_as': 'Luke Robins',
#    'mobile_name': 'Robins',
#    'object_id': '688373',
#    'player_id': '73461',
#    'player_primary_role': None,
#    'player_style_id': None,
#    'player_type': '5',
#    'player_type_name': 'sub fielder',
#    'popular_name': 'Robins',
#    'portrait_alt_id': '',
#    'portrait_object_id': '0',
#    'status_id': '3',
#    'team_abbreviation': 'SOA',
#    'team_id': '571',
#    'team_name': 'South Australia',
#    'team_short_name': 'South Aust'},
#   {'age_days': '304',
#    'age_years': '33',
#    'alpha_name': 'DOOLAN,AJ',
#    'batting_hand': 'right-hand batsman',
#    'batting_style': 'rhb',
#    'batting_style_long': 'right-hand bat',
#    'bowling_hand': 'unknown arm',
#    'bowling_pacespin': 'mixture/unknown',
#    'bowling_style': None,
#    'bowling_style_long': None,
#    'captain': '0',
#    'card_long': 'AJ Doolan',
#    'card_qualifier': '',
#    'card_short': 'AJ Doolan',
#    'dob': '1985-11-29',
#    'full_sub': '0',
#    'full_sub_innings': '0',
#    'full_sub_name': None,
#    'full_sub_overs': '0.0',
#    'full_sub_player_id': '0',
#    'keeper': '0',
#    'known_as': 'Alex Doolan',
#    'mobile_name': 'Doolan',
#    'object_id': '233648',
#    'player_id': '49203',
#    'player_primary_role': 'wicketkeeper batsman',
#    'player_style_id': '7',
#    'player_type': '5',
#    'player_type_name': 'sub fielder',
#    'popular_name': 'Doolan',
#    'portrait_alt_id': '1',
#    'portrait_object_id': '720155',
#    'status_id': '3',
#    'team_abbreviation': 'TAS',
#    'team_id': '611',
#    'team_name': 'Tasmania',
#    'team_short_name': 'Tasmania'},
#   {'age_days': '76',
#    'age_years': '19',
#    'alpha_name': 'FREEMAN,JA',
#    'batting_hand': 'right-hand batsman',
#    'batting_style': 'rhb',
#    'batting_style_long': 'right-hand bat',
#    'bowling_hand': 'right-arm bowler',
#    'bowling_pacespin': 'spin bowler',
#    'bowling_style': 'ob',
#    'bowling_style_long': 'right-arm offbreak ',
#    'captain': '0',
#    'card_long': 'JA Freeman',
#    'card_qualifier': '',
#    'card_short': 'JA Freeman',
#    'dob': '2000-07-15',
#    'full_sub': '0',
#    'full_sub_innings': '0',
#    'full_sub_name': None,
#    'full_sub_overs': '0.0',
#    'full_sub_player_id': '0',
#    'keeper': '0',
#    'known_as': 'Jarrod Freeman',
#    'mobile_name': 'Freeman',
#    'object_id': '1124288',
#    'player_id': '101345',
#    'player_primary_role': 'batsman',
#    'player_style_id': '8',
#    'player_type': '5',
#    'player_type_name': 'sub fielder',
# ...
#      'player_type_name': 'player',
#      'popular_name': 'Lehmann',
#      'portrait_alt_id': '',
#      'portrait_object_id': '0',
#      'status_id': '3'},
#     {'age_days': '165',
#      'age_years': '27',
#      'alpha_name': 'ROSS,AI',
#      'batting_hand': 'right-hand batsman',
#      'batting_style': 'rhb',
#      'batting_style_long': 'right-hand bat',
#      'bowling_hand': 'right-arm bowler',
#      'bowling_pacespin': 'spin bowler',
#      'bowling_style': 'ob',
#      'bowling_style_long': 'right-arm offbreak ',
#      'captain': '0',
#      'card_long': 'AI Ross',
#      'card_qualifier': '',
#      'card_short': 'Ross',
#      'dob': '1992-04-17',
#      'keeper': '0',
#      'known_as': 'Alex Ross',
#      'mobile_name': 'Ross',
#      'object_id': '333624',
#      'player_id': '55225',
#      'player_primary_role': 'middle-order batsman',
#      'player_style_id': '3',
#      'player_type': '1',
#      'player_type_name': 'player',
#      'popular_name': 'Ross',
#      'portrait_alt_id': '1',
#      'portrait_object_id': '1030743',
#      'status_id': '3'},
#     {'age_days': '23',
#      'age_years': '25',
#      'alpha_name': 'VALENTE,C',
#      'batting_hand': 'right-hand batsman',
#      'batting_style': 'rhb',
#      'batting_style_long': 'right-hand bat',
#      'bowling_hand': 'right-arm bowler',
#      'bowling_pacespin': 'pace bowler',
#      'bowling_style': 'rm',
#      'bowling_style_long': 'right-arm medium ',
#      'captain': '0',
#      'card_long': 'C Valente',
#      'card_qualifier': '',
#      'card_short': 'Valente',
#      'dob': '1994-09-06',
#      'keeper': '0',
#      'known_as': 'Cameron Valente',
#      'mobile_name': 'Valente',
#      'object_id': '605576',
#      'player_id': '70473',
#      'player_primary_role': None,
#      'player_style_id': None,
#      'player_type': '1',
#      'player_type_name': 'player',
#      'popular_name': 'Valente',
#      'portrait_alt_id': '1',
#      'portrait_object_id': '721175',
#      'status_id': '3'},
#     {'age_days': '279',
#      'age_years': '30',
#      'alpha_name': 'MENNIE,JM',
#      'batting_hand': 'right-hand batsman',
#      'batting_style': 'rhb',
#      'batting_style_long': 'right-hand bat',
#      'bowling_hand': 'right-arm bowler',
#      'bowling_pacespin': 'pace bowler',
#      'bowling_style': 'rfm',
#      'bowling_style_long': 'right-arm fast-medium ',
#      'captain': '0',
#      'card_long': 'JM Mennie',
#      'card_qualifier': '',
#      'card_short': 'Mennie',
#      'dob': '1988-12-24',
#      'keeper': '0',
#      'known_as': 'Joe Mennie',
#      'mobile_name': 'Mennie',
#      'object_id': '439288',
#      'player_id': '61826',
#      'player_primary_role': 'bowler',
#      'player_style_id': '4',
#      'player_type': '1',
#      'player_type_name': 'player',
#      'popular_name': 'Mennie',
#      'portrait_alt_id': '1',
#      'portrait_object_id': '478068',
#      'status_id': '3'},
#     {'age_days': '182',
#      'age_years': '27',
#      'alpha_name': 'ZAMPA,A',
#      'batting_hand': 'right-hand batsman',
#      'batting_style': 'rhb',
#      'batting_style_long': 'right-hand bat',
#      'bowling_hand': 'right-arm bowler',
#      'bowling_pacespin': 'spin bowler',
#      'bowling_style': 'lbg',
#      'bowling_style_long': 'legbreak googly ',
#      'captain': '0',
#      'card_long': 'A Zampa',
#      'card_qualifier': '',
#      'card_short': 'Zampa',
#      'dob': '1992-03-31',
#      'keeper': '0',
#      'known_as': 'Adam Zampa',
#      'mobile_name': 'Zampa',
#      'object_id': '379504',
#      'player_id': '58435',
#      'player_primary_role': 'bowler',
#      'player_style_id': '4',
#      'player_type': '1',
#      'player_type_name': 'player',
#      'popular_name': 'Zampa',
#      'portrait_alt_id': '1',
#      'portrait_object_id': '1099536',
#      'status_id': '3'},
#     {'age_days': '229',
#      'age_years': '28',
#      'alpha_name': 'RICHARDSON,KW',
#      'batting_hand': 'right-hand batsman',
#      'batting_style': 'rhb',
#      'batting_style_long': 'right-hand bat',
#      'bowling_hand': 'right-arm bowler',
#      'bowling_pacespin': 'pace bowler',
#      'bowling_style': 'rfm',
#      'bowling_style_long': 'right-arm fast-medium ',
#      'captain': '0',
#      'card_long': 'KW Richardson',
#      'card_qualifier': '',
#      'card_short': 'Richardson',
#      'dob': '1991-02-12',
#      'keeper': '0',
#      'known_as': 'Kane Richardson',
#      'mobile_name': 'Richardson',
#      'object_id': '272262',
#      'player_id': '50709',
#      'player_primary_role': 'bowler',
#      'player_style_id': '4',
#      'player_type': '1',
#      'player_type_name': 'player',
#      'popular_name': 'Kane',
#      'portrait_alt_id': '',
#      'portrait_object_id': '1186414',
#      'status_id': '3'},
#     {'age_days': '302',
#      'age_years': '19',
#      'alpha_name': 'POPE,L',
#      'batting_hand': 'right-hand batsman',
#      'batting_style': 'rhb',
#      'batting_style_long': 'right-hand bat',
#      'bowling_hand': 'right-arm bowler',
#      'bowling_pacespin': 'spin bowler',
#      'bowling_style': 'lbg',
#      'bowling_style_long': 'legbreak googly ',
#      'captain': '0',
#      'card_long': 'L Pope',
#      'card_qualifier': '',
#      'card_short': 'Pope',
#      'dob': '1999-12-01',
#      'keeper': '0',
#      'known_as': 'Lloyd Pope',
#      'mobile_name': 'Pope',
#      'object_id': '1076721',
#      'player_id': '96336',
#      'player_primary_role': 'bowler',
#      'player_style_id': '4',
#      'player_type': '1',
#      'player_type_name': 'player',
#      'popular_name': 'Pope',
#      'portrait_alt_id': '',
#      'portrait_object_id': '1132135',
#      'status_id': '3'}],
#    'players_in_side': '11',
#    'site_id': '931',
#    'team_abbreviation': 'SOA',
#    'team_filename': 'SOA',
#    'team_general_name': 'South Australia',
#    'team_id': '571',
#    'team_name': 'South Australia',
#    'team_short_name': 'South Aust',
#    'url_component': 'southaustralia'},
#   {'batsmen_in_side': '11',
#    'content_id': '611',
#    'country_id': '2',
#    'fielders_in_side': '11',
#    'logo_alt_id': '',
#    'logo_espncdn': 'N',
#    'logo_height': None,
#    'logo_image_height': '',
#    'logo_image_path': '',
#    'logo_image_width': '',
#    'logo_object_id': '0',
#    'logo_path': None,
#    'logo_width': None,
#    'object_id': '560',
#    'player': [{'age_days': '291',
#      'age_years': '24',
#      'alpha_name': 'MACDERMOTT,BR',
#      'batting_hand': 'right-hand batsman',
#      'batting_style': 'rhb',
#      'batting_style_long': 'right-hand bat',
#      'bowling_hand': 'right-arm bowler',
#      'bowling_pacespin': 'pace bowler',
#      'bowling_style': 'rm',
#      'bowling_style_long': 'right-arm medium ',
#      'captain': '0',
#      'card_long': 'BR McDermott',
#      'card_qualifier': '',
#      'card_short': 'McDermott',
#      'dob': '1994-12-12',
#      'keeper': '1',
#      'known_as': 'Ben McDermott',
#      'mobile_name': 'McDermott',
#      'object_id': '603410',
#      'player_id': '70392',
#      'player_primary_role': 'wicketkeeper batsman',
#      'player_style_id': '7',
#      'player_type': '1',
#      'player_type_name': 'player',
#      'popular_name': '',
#      'portrait_alt_id': '1',
#      'portrait_object_id': '721191',
#      'status_id': '3'},
#     {'age_days': '161',
#      'age_years': '22',
#      'alpha_name': 'JEWELL,CP',
#      'batting_hand': 'left-hand batsman',
#      'batting_style': 'lhb',
#      'batting_style_long': 'left-hand bat',
#      'bowling_hand': 'unknown arm',
#      'bowling_pacespin': 'mixture/unknown',
#      'bowling_style': None,
#      'bowling_style_long': None,
#      'captain': '0',
#      'card_long': 'CP Jewell',
#      'card_qualifier': '',
#      'card_short': 'Jewell',
#      'dob': '1997-04-21',
#      'keeper': '0',
#      'known_as': 'Caleb Jewell',
#      'mobile_name': 'Jewell',
#      'object_id': '834741',
#      'player_id': '80971',
#      'player_primary_role': None,
#      'player_style_id': None,
#      'player_type': '1',
#      'player_type_name': 'player',
#      'popular_name': 'Jewell',
#      'portrait_alt_id': '1',
#      'portrait_object_id': '901343',
#      'status_id': '3'},
#     {'age_days': '277',
#      'age_years': '31',
#      'alpha_name': 'WADE,MS',
#      'batting_hand': 'left-hand batsman',
#      'batting_style': 'lhb',
#      'batting_style_long': 'left-hand bat',
#      'bowling_hand': 'right-arm bowler',
#      'bowling_pacespin': 'pace bowler',
#      'bowling_style': 'rm',
#      'bowling_style_long': 'right-arm medium ',
#      'captain': '1',
#      'card_long': 'MS Wade',
#      'card_qualifier': '',
#      'card_short': 'Wade',
#      'dob': '1987-12-26',
#      'keeper': '0',
#      'known_as': 'Matthew Wade',
#      'mobile_name': 'Wade',
#      'object_id': '230193',
#      'player_id': '49024',
#      'player_primary_role': 'wicketkeeper batsman',
#      'player_style_id': '7',
#      'player_type': '1',
#      'player_type_name': 'player',
#      'popular_name': 'Wade',
#      'portrait_alt_id': '1',
#      'portrait_object_id': '1099501',
#      'status_id': '3'},
#     {'age_days': '169',
#      'age_years': '27',
#      'alpha_name': 'SILK,JC',
#      'batting_hand': 'right-hand batsman',
#      'batting_style': 'rhb',
#      'batting_style_long': 'right-hand bat',
#      'bowling_hand': 'unknown arm',
#      'bowling_pacespin': 'mixture/unknown',
#      'bowling_style': None,
#      'bowling_style_long': None,
#      'captain': '0',
#      'card_long': 'JC Silk',
#      'card_qualifier': '',
#      'card_short': 'Silk',
#      'dob': '1992-04-13',
#      'keeper': '0',
#      'known_as': 'Jordan Silk',
#      'mobile_name': 'Silk',
#      'object_id': '437669',
#      'player_id': '61749',
#      'player_primary_role': 'middle-order batsman',
#      'player_style_id': '3',
#      'player_type': '1',
#      'player_type_name': 'player',
#      'popular_name': 'Silk',
#      'portrait_alt_id': '',
#      'portrait_object_id': '0',
#      'status_id': '3'},
#     {'age_days': '22',
#      'age_years': '37',
#      'alpha_name': 'BAILEY,GJ',
#      'batting_hand': 'right-hand batsman',
#      'batting_style': 'rhb',
#      'batting_style_long': 'right-hand bat',
#      'bowling_hand': 'right-arm bowler',
#      'bowling_pacespin': 'pace bowler',
#      'bowling_style': 'rm',
#      'bowling_style_long': 'right-arm medium ',
#      'captain': '0',
#      'card_long': 'GJ Bailey',
#      'card_qualifier': '',
#      'card_short': 'Bailey',
#      'dob': '1982-09-07',
#      'keeper': '0',
#      'known_as': 'George Bailey',
#      'mobile_name': 'Bailey',
#      'object_id': '4451',
#      'player_id': '35384',
#      'player_primary_role': 'top-order batsman',
#      'player_style_id': '2',
#      'player_type': '1',
#      'player_type_name': 'player',
#      'popular_name': 'Bailey',
#      'portrait_alt_id': '1',
#      'portrait_object_id': '817087',
#      'status_id': '3'},
#     {'age_days': '302',
#      'age_years': '25',
#      'alpha_name': 'WEBSTER,BJ',
#      'batting_hand': 'right-hand batsman',
#      'batting_style': 'rhb',
#      'batting_style_long': 'right-hand bat',
#      'bowling_hand': 'right-arm bowler',
#      'bowling_pacespin': 'spin bowler',
#      'bowling_style': 'ob',
#      'bowling_style_long': 'right-arm offbreak ',
#      'captain': '0',
#      'card_long': 'BJ Webster',
#      'card_qualifier': '',
#      'card_short': 'Webster',
#      'dob': '1993-12-01',
#      'keeper': '0',
#      'known_as': 'Beau Webster',
#      'mobile_name': 'Webster',
#      'object_id': '381329',
#      'player_id': '58730',
#      'player_primary_role': 'allrounder',
#      'player_style_id': '5',
#      'player_type': '1',
#      'player_type_name': 'player',
#      'popular_name': 'Webster',
#      'portrait_alt_id': '',
#      'portrait_object_id': '0',
#      'status_id': '3'},
#     {'age_days': '153',
#      'age_years': '29',
#      'alpha_name': 'FAULKNER,JP',
#      'batting_hand': 'right-hand batsman',
#      'batting_style': 'rhb',
#      'batting_style_long': 'right-hand bat',
#      'bowling_hand': 'left-arm bowler',
#      'bowling_pacespin': 'pace bowler',
#      'bowling_style': 'lfm',
#      'bowling_style_long': 'left-arm fast-medium ',
#      'captain': '0',
#      'card_long': 'JP Faulkner',
#      'card_qualifier': '',
#      'card_short': 'Faulkner',
#      'dob': '1990-04-29',
#      'keeper': '0',
#      'known_as': 'James Faulkner',
#      'mobile_name': 'Faulkner',
#      'object_id': '270484',
#      'player_id': '50483',
#      'player_primary_role': 'bowling allrounder',
#      'player_style_id': '11',
#      'player_type': '1',
#      'player_type_name': 'player',
#      'popular_name': 'Faulkner',
#      'portrait_alt_id': '',
#      'portrait_object_id': '1030005',
#      'status_id': '3'},
#     {'age_days': '107',
#      'age_years': '26',
#      'alpha_name': 'SANDHU,GS',
#      'batting_hand': 'left-hand batsman',
#      'batting_style': 'lhb',
#      'batting_style_long': 'left-hand bat',
#      'bowling_hand': 'right-arm bowler',
#      'bowling_pacespin': 'pace bowler',
#      'bowling_style': 'rfm',
#      'bowling_style_long': 'right-arm fast-medium ',
#      'captain': '0',
#      'card_long': 'GS Sandhu',
#      'card_qualifier': '',
#      'card_short': 'Sandhu',
#      'dob': '1993-06-14',
#      'keeper': '0',
#      'known_as': 'Gurinder Sandhu',
#      'mobile_name': 'Sandhu',
#      'object_id': '499660',
#      'player_id': '64707',
#      'player_primary_role': 'bowler',
#      'player_style_id': '4',
#      'player_type': '1',
#      'player_type_name': 'player',
#      'popular_name': 'Sandhu',
#      'portrait_alt_id': '1',
#      'portrait_object_id': '575824',
#      'status_id': '3'},
#     {'age_days': '7',
#      'age_years': '25',
#      'alpha_name': 'ELLIS,NT',
#      'batting_hand': 'right-hand batsman',
#      'batting_style': 'rhb',
#      'batting_style_long': 'right-hand bat',
#      'bowling_hand': 'right-arm bowler',
#      'bowling_pacespin': 'pace bowler',
#      'bowling_style': 'rm',
#      'bowling_style_long': 'right-arm medium ',
#      'captain': '0',
#      'card_long': 'NT Ellis',
#      'card_qualifier': '',
#      'card_short': 'Ellis',
#      'dob': '1994-09-22',
#      'keeper': '0',
#      'known_as': 'Nathan Ellis',
#      'mobile_name': 'Ellis',
#      'object_id': '826915',
#      'player_id': '80817',
#      'player_primary_role': None,
#      'player_style_id': None,
#      'player_type': '1',
#      'player_type_name': 'player',
#      'popular_name': 'Ellis',
#      'portrait_alt_id': '',
#      'portrait_object_id': '0',
#      'status_id': '3'},
#     {'age_days': '292',
#      'age_years': '32',
#      'alpha_name': 'BIRD,JM',
#      'batting_hand': 'right-hand batsman',
#      'batting_style': 'rhb',
#      'batting_style_long': 'right-hand bat',
#      'bowling_hand': 'right-arm bowler',
#      'bowling_pacespin': 'pace bowler',
#      'bowling_style': 'rfm',
#      'bowling_style_long': 'right-arm fast-medium ',
#      'captain': '0',
#      'card_long': 'JM Bird',
#      'card_qualifier': '',
#      'card_short': 'Bird',
#      'dob': '1986-12-11',
#      'keeper': '0',
#      'known_as': 'Jackson Bird',
#      'mobile_name': 'Bird',
#      'object_id': '215152',
#      'player_id': '48669',
#      'player_primary_role': 'bowler',
#      'player_style_id': '4',
#      'player_type': '1',
#      'player_type_name': 'player',
#      'popular_name': 'Bird',
#      'portrait_alt_id': '1',
#      'portrait_object_id': '632230',
#      'status_id': '3'},
#     {'age_days': '100',
#      'age_years': '23',
#      'alpha_name': 'MEREDITH,RP',
#      'batting_hand': 'left-hand batsman',
#      'batting_style': 'lhb',
#      'batting_style_long': 'left-hand bat',
#      'bowling_hand': 'right-arm bowler',
#      'bowling_pacespin': 'pace bowler',
#      'bowling_style': 'rf',
#      'bowling_style_long': 'right-arm fast ',
#      'captain': '0',
#      'card_long': 'RP Meredith',
#      'card_qualifier': '',
#      'card_short': 'Meredith',
#      'dob': '1996-06-21',
#      'keeper': '0',
#      'known_as': 'Riley Meredith',
#      'mobile_name': 'Meredith',
#      'object_id': '961713',
#      'player_id': '89779',
#      'player_primary_role': 'bowler',
#      'player_style_id': '4',
#      'player_type': '1',
#      'player_type_name': 'player',
#      'popular_name': 'Meredith',
#      'portrait_alt_id': '',
#      'portrait_object_id': '0',
#      'status_id': '3'}],
#    'players_in_side': '11',
#    'site_id': '932',
#    'team_abbreviation': 'TAS',
#    'team_filename': 'TAS',
#    'team_general_name': 'Tasmania',
#    'team_id': '611',
#    'team_name': 'Tasmania',
#    'team_short_name': 'Tasmania',
#    'url_component': 'tasmania'}],
#  'tiebreaker': [],
#  'weather': {'forecast': []}}
